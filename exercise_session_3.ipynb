# %% [markdown]
# ### Exercise 1

# %% [markdown]
# A- Describe the following graph using natural language sentences.
#
# B- Draw a graph that represents the RDF/S model.

# %% [markdown]
# <img src="https://git.science.uu.nl/islak001/images/-/raw/master/1.png" width="500" height="500">

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# List all the triples that can be inferred from the following graph.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# List all the triples that can be inferred from the following graph.

# %% [markdown]
# <img src="https://git.science.uu.nl/islak001/images/-/raw/master/3.png" width="500" >

# %% [markdown]
# ### Exercise 4

# %% [markdown]
# Get OWL-RL package from https://github.com/RDFLib/OWL-RL.
#
# Copy the folder into the directory that contains your Python files. Then run python setup.py install inside the OWL-RL folder.
#
# Use OWL-RL to check your answers for exercise 2 and 3.
#
# Documentation: https://owl-rl.readthedocs.io/en/latest/OWLRL.html

# %% [markdown]
# # SPARQL

# %% [markdown]
# ### Exercise 1: Using local RDF data

# %%
from rdflib import Graph

g = Graph()
g.parse("volcano.ttl", format='turtle')
print(g.serialize(format="turtle"))
# Out:
# @prefix dbpedia: <http://dbpedia.org/resource/> .
# @prefix p: <http://example.org/terms/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix umbel_sc: <http://umbel.org/umbel/sc/> .
#
# dbpedia:Beerenberg a umbel_sc:NaturalElevation,
#         umbel_sc:Volcano ;
#     rdfs:label "Beerenberg"@en,
#         "Беренберг"@ru .
#
# dbpedia:Mount_Baker a umbel_sc:Volcano ;
#     p:location dbpedia:United_States .
#
# dbpedia:Mount_Etna a umbel_sc:Volcano ;
#     rdfs:label "Etna" .
#
# dbpedia:United_States rdfs:label "United States" .

# %% [markdown]
# ### Provide SPARQL queries for the following questions:
# A- What are the names of all (known) volcanos?

# %% [markdown]
# B- What are all volcanos and their names?

# %% [markdown]
# ### Exercise 2: Using remote RDF data

# %% [markdown]
# ### Provide queries for the following questions:
# A- List the awards (http://dbpedia.org/ontology/award) that Albert Einstein received.
#
# RDF graph: DBpedia (http://dbpedia.org/resource/Albert_Einstein)

# %% [markdown]
# B- Select all the winners of the Noble prize in physics.
#
# RDF graph: DBpedia (http://dbpedia.org/resource/Nobel_Prize_in_Physics)

# %% [markdown]
# C- Select winners of the Noble prize in physics who are Dutch.
#
# RDF graph: DBpedia (http://dbpedia.org/resource/Nobel_Prize_in_Physics)

# %% [markdown]
# D- Select winners of the Noble prize in physics who are Dutch or German.
#
# RDF graph: DBpedia (http://dbpedia.org/resource/Nobel_Prize_in_Physics)

# %% [markdown]
# ### Exercise 3: Using a remote SPARQL endpoint

# %% [markdown]
# ### Provide queries for the following questions:
# A- Select winners of the Noble prize in physics who have dual nationalities.
#
# RDF graph: DBpedia (http://dbpedia.org/resource/Nobel_Prize_in_Physics)
#
# SPARQL endpoint: https://dbpedia.org/sparql

# %% [markdown]
# B- Select winners of the Noble prize in physics who won after 2000.
#
# RDF graph: Wikidata.org
#
# • SPARQL endpoint: https://query.wikidata.org

# %% [markdown]
# C- Extend the above query such that the names of the winners can be selected.
